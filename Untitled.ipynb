# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import plot_model
from sklearn import tree, svm, datasets, metrics
from sklearn.model_selection import train_test_split,StratifiedKFold, ShuffleSplit
from sklearn.model_selection import StratifiedShuffleSplit, cross_validate, GridSearchCV, learning_curve
from sklearn.metrics import roc_curve, auc, accuracy_score, confusion_matrix, classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.pipeline import Pipeline
from utilities import plot_2d_data, plot_2d_classifier, plot_confusionmatrix
from utilities import learning_curve_model, validation_curve_model, plot_learning_curve
from scipy import stats
import seaborn as sns
import os
import timeit

from utilities import get_colors
cm = get_colors(colormap='RdBu', n_colors=2)

# %%
data = pd.read_csv("./data/bank.csv")
data.shape
# Out:
# (11162, 17)

# %%
data.head(5)
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
data = data.apply(LabelEncoder().fit_transform)
data.head(5)
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   41    0        1          1        0     2288        1     0        2
# 1   38    0        1          1        0      469        0     0        2
# 2   23    9        1          1        0     1618        1     0        2
# 3   37    7        1          1        0     2356        1     0        2
# 4   36    0        1          2        0      608        0     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome  deposit
# 0    4      8      1021         0      0         0         3        1
# 1    4      8      1283         0      0         0         3        1
# 2    4      8      1246         0      0         0         3        1
# 3    4      8       577         0      0         0         3        1
# 4    4      8       671         1      0         0         3        1

# %%
data_X = data.drop(columns = ['deposit'], axis=1)/256
data_y = data['deposit']
train_X, test_X, train_y, test_y = train_test_split(data_X, data_y, test_size=0.2, random_state=100)

# %%
cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=0)

# %%
dtc = tree.DecisionTreeClassifier(random_state=100)
dtc.fit(train_X, train_y)
# Out:
# DecisionTreeClassifier(random_state=100)

# %%
train_size=np.linspace(.1, 1.0, 15)
learning_curve_model(data_X, data_y, dtc, cv, train_size)
plt.show()

# %%
predict_y_train = dtc.predict(train_X)
predict_y = dtc.predict(test_X)
print(f"Training accuracy score: {100* accuracy_score(train_y, predict_y_train)}%")
print(f"Testing accuracy Score: {100* accuracy_score(test_y, predict_y)}%")
# Out:
# Training accuracy score: 100.0%
# Testing accuracy Score: 78.28034034930586%

# %%
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=0)

title = "Learning Curves (Unpruned Decision Tree)"
dtc = tree.DecisionTreeClassifier(random_state=100)
plot_learning_curve(dtc, title, train_X, train_y, axes=axes[0, :], ylim=(0.7, 1.01),
                    cv=cv, n_jobs=4)

title = "Learning Curves (Pre-pruned Decision Tree)"
dtc_pre = tree.DecisionTreeClassifier(max_depth=8, min_samples_leaf=2, min_samples_split=3)
plot_learning_curve(dtc_pre, title, train_X, train_y, axes=axes[1,:], ylim=(0.7, 1.01),
                    cv=cv, n_jobs=4)


plt.show()

# %% [markdown]
# ### Neural Network

# %%
#fig, axes = plt.subplots(3, 1, figsize=(15, 15))

#cv = ShuffleSplit(n_splits=10, test_size=0.2, random_state=0)

#title = "Learning Curves (5 layer MLP)"
#clf1 = MLPClassifier(alpha=1e-5, hidden_layer_sizes=(5,), solver='sgd', max_iter=10000, random_state=18)
#clf1.fit(train_X, train_y)
#plt.subplot(clf1.loss_curve_)
#plot_learning_curve(clf1, title, train_X, train_y, axes=axes[0, :], ylim=(0.7, 1.01), cv=cv, n_jobs=4)

#title = "Learning Curves (10 layer MLP)"
#clf2 = MLPClassifier(alpha=1e-5, hidden_layer_sizes=(10,), solver='sgd', max_iter=10000, random_state=18)
#clf2.fit(train_X, train_y)
#plt.subplot(clf2.loss_curve_)
# plot_learning_curve(clf2, title, train_X, train_y, axes=axes[1,:], ylim=(0.7, 1.01),cv=cv, n_jobs=4)

#title = "Learning Curves (15 layer MLP)"
#clf3 = MLPClassifier(alpha=1e-5, hidden_layer_sizes=(15,), solver='sgd', max_iter=10000, random_state=18)
#clf3.fit(train_X, train_y)
#plt.subplot(clf3.loss_curve_)
# plot_learning_curve(clf3, title, train_X, train_y, axes=axes[2,:], ylim=(0.7, 1.01), cv=cv, n_jobs=4)


#plt.show()

# %%
model = Sequential([
    Dense(32, activation='relu', input_shape=(16,)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid'),
])

# %%
model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
train2_X, val_X, train2_y, val_y = train_test_split(train_X, train_y, test_size=0.2, random_state=100)

hist = model.fit(train2_X, train2_y,
          batch_size=32, epochs=150,
          validation_data=(val_X, val_y))
# Out:
# Epoch 1/150
# 224/224 [==============================] - 0s 879us/step - loss: 0.4822 - accuracy: 0.7724 - val_loss: 0.4857 - val_accuracy: 0.7704
# Epoch 2/150
# 224/224 [==============================] - 0s 759us/step - loss: 0.4812 - accuracy: 0.7742 - val_loss: 0.5375 - val_accuracy: 0.7464
# Epoch 3/150
# 224/224 [==============================] - 0s 813us/step - loss: 0.4813 - accuracy: 0.7739 - val_loss: 0.4895 - val_accuracy: 0.7671
# Epoch 4/150
# 224/224 [==============================] - 0s 790us/step - loss: 0.4822 - accuracy: 0.7747 - val_loss: 0.4900 - val_accuracy: 0.7704
# Epoch 5/150
# 224/224 [==============================] - 0s 744us/step - loss: 0.4808 - accuracy: 0.7768 - val_loss: 0.5272 - val_accuracy: 0.7301
# Epoch 6/150
# 224/224 [==============================] - 0s 768us/step - loss: 0.4823 - accuracy: 0.7715 - val_loss: 0.5001 - val_accuracy: 0.7620
# Epoch 7/150
# 224/224 [==============================] - 0s 794us/step - loss: 0.4810 - accuracy: 0.7726 - val_loss: 0.4974 - val_accuracy: 0.7620
# Epoch 8/150
# 224/224 [==============================] - 0s 931us/step - loss: 0.4824 - accuracy: 0.7698 - val_loss: 0.5516 - val_accuracy: 0.7178
# Epoch 9/150
# 224/224 [==============================] - 0s 813us/step - loss: 0.4829 - accuracy: 0.7729 - val_loss: 0.4877 - val_accuracy: 0.7665
# Epoch 10/150
# 224/224 [==============================] - 0s 764us/step - loss: 0.4820 - accuracy: 0.7712 - val_loss: 0.5147 - val_accuracy: 0.7396
# Epoch 11/150
# 224/224 [==============================] - 0s 772us/step - loss: 0.4812 - accuracy: 0.7740 - val_loss: 0.4962 - val_accuracy: 0.7637
# Epoch 12/150
# 224/224 [==============================] - 0s 776us/step - loss: 0.4817 - accuracy: 0.7718 - val_loss: 0.5068 - val_accuracy: 0.7469
# Epoch 13/150
# 224/224 [==============================] - 0s 781us/step - loss: 0.4819 - accuracy: 0.7725 - val_loss: 0.4973 - val_accuracy: 0.7643
# Epoch 14/150
# 224/224 [==============================] - 0s 829us/step - loss: 0.4820 - accuracy: 0.7733 - val_loss: 0.5018 - val_accuracy: 0.7620
# Epoch 15/150
# 224/224 [==============================] - 0s 803us/step - loss: 0.4804 - accuracy: 0.7721 - val_loss: 0.4930 - val_accuracy: 0.7660
# Epoch 16/150
# 224/224 [==============================] - 0s 773us/step - loss: 0.4814 - accuracy: 0.7712 - val_loss: 0.4941 - val_accuracy: 0.7615
# Epoch 17/150
# 224/224 [==============================] - 0s 807us/step - loss: 0.4812 - accuracy: 0.7719 - val_loss: 0.4886 - val_accuracy: 0.7660
# Epoch 18/150
# 224/224 [==============================] - 0s 834us/step - loss: 0.4812 - accuracy: 0.7735 - val_loss: 0.5037 - val_accuracy: 0.7480
# Epoch 19/150
# 224/224 [==============================] - 0s 751us/step - loss: 0.4807 - accuracy: 0.7763 - val_loss: 0.4883 - val_accuracy: 0.7665
# Epoch 20/150
# 224/224 [==============================] - 0s 877us/step - loss: 0.4821 - accuracy: 0.7694 - val_loss: 0.5017 - val_accuracy: 0.7615
# Epoch 21/150
# 224/224 [==============================] - 0s 841us/step - loss: 0.4811 - accuracy: 0.7731 - val_loss: 0.4865 - val_accuracy: 0.7688
# Epoch 22/150
# 224/224 [==============================] - 0s 743us/step - loss: 0.4809 - accuracy: 0.7726 - val_loss: 0.4868 - val_accuracy: 0.7693
# Epoch 23/150
# 224/224 [==============================] - 0s 763us/step - loss: 0.4813 - accuracy: 0.7718 - val_loss: 0.4981 - val_accuracy: 0.7598
# Epoch 24/150
# 224/224 [==============================] - 0s 735us/step - loss: 0.4824 - accuracy: 0.7704 - val_loss: 0.4975 - val_accuracy: 0.7643
# Epoch 25/150
# 224/224 [==============================] - 0s 820us/step - loss: 0.4820 - accuracy: 0.7715 - val_loss: 0.5110 - val_accuracy: 0.7570
# Epoch 26/150
# 224/224 [==============================] - 0s 760us/step - loss: 0.4811 - accuracy: 0.7717 - val_loss: 0.4869 - val_accuracy: 0.7693
# Epoch 27/150
# 224/224 [==============================] - 0s 779us/step - loss: 0.4801 - accuracy: 0.7732 - val_loss: 0.4877 - val_accuracy: 0.7632
# Epoch 28/150
# 224/224 [==============================] - 0s 740us/step - loss: 0.4809 - accuracy: 0.7735 - val_loss: 0.4851 - val_accuracy: 0.7671
# Epoch 29/150
# 224/224 [==============================] - 0s 794us/step - loss: 0.4802 - accuracy: 0.7710 - val_loss: 0.4884 - val_accuracy: 0.7660
# Epoch 30/150
# 224/224 [==============================] - 0s 759us/step - loss: 0.4812 - accuracy: 0.7705 - val_loss: 0.5066 - val_accuracy: 0.7548
# Epoch 31/150
# 224/224 [==============================] - 0s 809us/step - loss: 0.4821 - accuracy: 0.7704 - val_loss: 0.4880 - val_accuracy: 0.7676
# Epoch 32/150
# 224/224 [==============================] - 0s 754us/step - loss: 0.4800 - accuracy: 0.7731 - val_loss: 0.4864 - val_accuracy: 0.7704
# Epoch 33/150
# 224/224 [==============================] - 0s 761us/step - loss: 0.4798 - accuracy: 0.7731 - val_loss: 0.5316 - val_accuracy: 0.7430
# Epoch 34/150
# 224/224 [==============================] - 0s 817us/step - loss: 0.4807 - accuracy: 0.7705 - val_loss: 0.4852 - val_accuracy: 0.7704
# Epoch 35/150
# 224/224 [==============================] - 0s 806us/step - loss: 0.4812 - accuracy: 0.7721 - val_loss: 0.4863 - val_accuracy: 0.7688
# Epoch 36/150
# 224/224 [==============================] - 0s 781us/step - loss: 0.4803 - accuracy: 0.7708 - val_loss: 0.4975 - val_accuracy: 0.7576
# Epoch 37/150
# 224/224 [==============================] - 0s 850us/step - loss: 0.4797 - accuracy: 0.7739 - val_loss: 0.4973 - val_accuracy: 0.7676
# Epoch 38/150
# 224/224 [==============================] - 0s 794us/step - loss: 0.4820 - accuracy: 0.7708 - val_loss: 0.5304 - val_accuracy: 0.7475
# Epoch 39/150
# 224/224 [==============================] - 0s 762us/step - loss: 0.4803 - accuracy: 0.7721 - val_loss: 0.5030 - val_accuracy: 0.7620
# Epoch 40/150
# 224/224 [==============================] - 0s 796us/step - loss: 0.4804 - accuracy: 0.7729 - val_loss: 0.4944 - val_accuracy: 0.7648
# Epoch 41/150
# 224/224 [==============================] - 0s 784us/step - loss: 0.4812 - accuracy: 0.7708 - val_loss: 0.5222 - val_accuracy: 0.7346
# Epoch 42/150
# 224/224 [==============================] - 0s 810us/step - loss: 0.4798 - accuracy: 0.7760 - val_loss: 0.5131 - val_accuracy: 0.7441
# Epoch 43/150
# 224/224 [==============================] - 0s 764us/step - loss: 0.4808 - accuracy: 0.7715 - val_loss: 0.4869 - val_accuracy: 0.7676
# Epoch 44/150
# 224/224 [==============================] - 0s 799us/step - loss: 0.4801 - accuracy: 0.7717 - val_loss: 0.4991 - val_accuracy: 0.7615
# Epoch 45/150
# 224/224 [==============================] - 0s 814us/step - loss: 0.4809 - accuracy: 0.7698 - val_loss: 0.4913 - val_accuracy: 0.7632
# Epoch 46/150
# 224/224 [==============================] - 0s 750us/step - loss: 0.4811 - accuracy: 0.7754 - val_loss: 0.4966 - val_accuracy: 0.7598
# Epoch 47/150
# 224/224 [==============================] - 0s 759us/step - loss: 0.4808 - accuracy: 0.7676 - val_loss: 0.5005 - val_accuracy: 0.7520
# Epoch 48/150
# 224/224 [==============================] - 0s 809us/step - loss: 0.4800 - accuracy: 0.7742 - val_loss: 0.5004 - val_accuracy: 0.7559
# Epoch 49/150
# 224/224 [==============================] - 0s 768us/step - loss: 0.4806 - accuracy: 0.7708 - val_loss: 0.4853 - val_accuracy: 0.7671
# Epoch 50/150
# 224/224 [==============================] - 0s 777us/step - loss: 0.4779 - accuracy: 0.7775 - val_loss: 0.4891 - val_accuracy: 0.7637
# Epoch 51/150
# 224/224 [==============================] - 0s 777us/step - loss: 0.4799 - accuracy: 0.7703 - val_loss: 0.4992 - val_accuracy: 0.7637
# Epoch 52/150
# 224/224 [==============================] - 0s 758us/step - loss: 0.4797 - accuracy: 0.7742 - val_loss: 0.4902 - val_accuracy: 0.7643
# Epoch 53/150
# 224/224 [==============================] - 0s 768us/step - loss: 0.4795 - accuracy: 0.7722 - val_loss: 0.5023 - val_accuracy: 0.7564
# Epoch 54/150
# 224/224 [==============================] - 0s 777us/step - loss: 0.4805 - accuracy: 0.7722 - val_loss: 0.5017 - val_accuracy: 0.7626
# Epoch 55/150
# 224/224 [==============================] - 0s 804us/step - loss: 0.4787 - accuracy: 0.7745 - val_loss: 0.4954 - val_accuracy: 0.7626
# Epoch 56/150
# 224/224 [==============================] - 0s 826us/step - loss: 0.4811 - accuracy: 0.7704 - val_loss: 0.4851 - val_accuracy: 0.7682
# Epoch 57/150
# 224/224 [==============================] - 0s 865us/step - loss: 0.4794 - accuracy: 0.7690 - val_loss: 0.4980 - val_accuracy: 0.7648
# Epoch 58/150
# 224/224 [==============================] - 0s 886us/step - loss: 0.4797 - accuracy: 0.7714 - val_loss: 0.4852 - val_accuracy: 0.7676
# Epoch 59/150
# 224/224 [==============================] - 0s 827us/step - loss: 0.4802 - accuracy: 0.7722 - val_loss: 0.4849 - val_accuracy: 0.7693
# Epoch 60/150
# 224/224 [==============================] - 0s 763us/step - loss: 0.4802 - accuracy: 0.7721 - val_loss: 0.5287 - val_accuracy: 0.7357
# Epoch 61/150
# 224/224 [==============================] - 0s 772us/step - loss: 0.4803 - accuracy: 0.7698 - val_loss: 0.4860 - val_accuracy: 0.7688
# Epoch 62/150
# 224/224 [==============================] - 0s 736us/step - loss: 0.4799 - accuracy: 0.7749 - val_loss: 0.4982 - val_accuracy: 0.7564
# Epoch 63/150
# 224/224 [==============================] - 0s 780us/step - loss: 0.4802 - accuracy: 0.7718 - val_loss: 0.4854 - val_accuracy: 0.7654
# Epoch 64/150
# 224/224 [==============================] - 0s 879us/step - loss: 0.4786 - accuracy: 0.7747 - val_loss: 0.4920 - val_accuracy: 0.7660
# Epoch 65/150
# 224/224 [==============================] - 0s 872us/step - loss: 0.4786 - accuracy: 0.7714 - val_loss: 0.4877 - val_accuracy: 0.7676
# Epoch 66/150
# 224/224 [==============================] - 0s 772us/step - loss: 0.4791 - accuracy: 0.7733 - val_loss: 0.4908 - val_accuracy: 0.7682
# Epoch 67/150
# 224/224 [==============================] - 0s 762us/step - loss: 0.4799 - accuracy: 0.7721 - val_loss: 0.4946 - val_accuracy: 0.7587
# Epoch 68/150
# 224/224 [==============================] - 0s 743us/step - loss: 0.4793 - accuracy: 0.7717 - val_loss: 0.4858 - val_accuracy: 0.7682
# Epoch 69/150
# 224/224 [==============================] - 0s 788us/step - loss: 0.4783 - accuracy: 0.7743 - val_loss: 0.5109 - val_accuracy: 0.7486
# Epoch 70/150
# 224/224 [==============================] - 0s 866us/step - loss: 0.4787 - accuracy: 0.7760 - val_loss: 0.5100 - val_accuracy: 0.7559
# Epoch 71/150
# 224/224 [==============================] - 0s 849us/step - loss: 0.4791 - accuracy: 0.7725 - val_loss: 0.4845 - val_accuracy: 0.7744
# Epoch 72/150
# 224/224 [==============================] - 0s 820us/step - loss: 0.4793 - accuracy: 0.7712 - val_loss: 0.5023 - val_accuracy: 0.7587
# Epoch 73/150
# 224/224 [==============================] - 0s 835us/step - loss: 0.4789 - accuracy: 0.7735 - val_loss: 0.4866 - val_accuracy: 0.7755
# Epoch 74/150
# 224/224 [==============================] - 0s 741us/step - loss: 0.4784 - accuracy: 0.7742 - val_loss: 0.5395 - val_accuracy: 0.7436
# Epoch 75/150
# 224/224 [==============================] - 0s 784us/step - loss: 0.4795 - accuracy: 0.7733 - val_loss: 0.5350 - val_accuracy: 0.7296
# Epoch 76/150
# 224/224 [==============================] - 0s 755us/step - loss: 0.4801 - accuracy: 0.7726 - val_loss: 0.4944 - val_accuracy: 0.7693
# Epoch 77/150
# 224/224 [==============================] - 0s 798us/step - loss: 0.4774 - accuracy: 0.7717 - val_loss: 0.4851 - val_accuracy: 0.7688
# Epoch 78/150
# 224/224 [==============================] - 0s 761us/step - loss: 0.4794 - accuracy: 0.7726 - val_loss: 0.4957 - val_accuracy: 0.7609
# Epoch 79/150
# 224/224 [==============================] - 0s 790us/step - loss: 0.4781 - accuracy: 0.7764 - val_loss: 0.5063 - val_accuracy: 0.7503
# Epoch 80/150
# 224/224 [==============================] - 0s 792us/step - loss: 0.4795 - accuracy: 0.7732 - val_loss: 0.5140 - val_accuracy: 0.7441
# Epoch 81/150
# 224/224 [==============================] - 0s 810us/step - loss: 0.4782 - accuracy: 0.7756 - val_loss: 0.5176 - val_accuracy: 0.7430
# Epoch 82/150
# 224/224 [==============================] - 0s 749us/step - loss: 0.4799 - accuracy: 0.7732 - val_loss: 0.4882 - val_accuracy: 0.7660
# Epoch 83/150
# 224/224 [==============================] - 0s 782us/step - loss: 0.4791 - accuracy: 0.7722 - val_loss: 0.4882 - val_accuracy: 0.7693
# Epoch 84/150
# 224/224 [==============================] - 0s 734us/step - loss: 0.4789 - accuracy: 0.7719 - val_loss: 0.4842 - val_accuracy: 0.7682
# Epoch 85/150
# 224/224 [==============================] - 0s 767us/step - loss: 0.4788 - accuracy: 0.7739 - val_loss: 0.5338 - val_accuracy: 0.7396
# Epoch 86/150
# 224/224 [==============================] - 0s 753us/step - loss: 0.4792 - accuracy: 0.7721 - val_loss: 0.5015 - val_accuracy: 0.7598
# Epoch 87/150
# 224/224 [==============================] - 0s 774us/step - loss: 0.4786 - accuracy: 0.7739 - val_loss: 0.4909 - val_accuracy: 0.7620
# Epoch 88/150
# 224/224 [==============================] - 0s 776us/step - loss: 0.4792 - accuracy: 0.7715 - val_loss: 0.4892 - val_accuracy: 0.7727
# Epoch 89/150
# 224/224 [==============================] - 0s 774us/step - loss: 0.4793 - accuracy: 0.7733 - val_loss: 0.4850 - val_accuracy: 0.7688
# Epoch 90/150
# 224/224 [==============================] - 0s 778us/step - loss: 0.4791 - accuracy: 0.7726 - val_loss: 0.4943 - val_accuracy: 0.7609
# Epoch 91/150
# 224/224 [==============================] - 0s 748us/step - loss: 0.4781 - accuracy: 0.7733 - val_loss: 0.5008 - val_accuracy: 0.7570
# Epoch 92/150
# 224/224 [==============================] - 0s 804us/step - loss: 0.4795 - accuracy: 0.7771 - val_loss: 0.4892 - val_accuracy: 0.7704
# Epoch 93/150
# 224/224 [==============================] - 0s 874us/step - loss: 0.4789 - accuracy: 0.7705 - val_loss: 0.4847 - val_accuracy: 0.7738
# Epoch 94/150
# 224/224 [==============================] - 0s 857us/step - loss: 0.4786 - accuracy: 0.7756 - val_loss: 0.4948 - val_accuracy: 0.7632
# Epoch 95/150
# 224/224 [==============================] - 0s 829us/step - loss: 0.4785 - accuracy: 0.7726 - val_loss: 0.4933 - val_accuracy: 0.7626
# Epoch 96/150
# 224/224 [==============================] - 0s 761us/step - loss: 0.4789 - accuracy: 0.7759 - val_loss: 0.5250 - val_accuracy: 0.7340
# Epoch 97/150
# 224/224 [==============================] - 0s 762us/step - loss: 0.4798 - accuracy: 0.7738 - val_loss: 0.4856 - val_accuracy: 0.7660
# Epoch 98/150
# 224/224 [==============================] - 0s 818us/step - loss: 0.4786 - accuracy: 0.7732 - val_loss: 0.4849 - val_accuracy: 0.7710
# Epoch 99/150
# 224/224 [==============================] - 0s 747us/step - loss: 0.4792 - accuracy: 0.7731 - val_loss: 0.4873 - val_accuracy: 0.7660
# Epoch 100/150
# 224/224 [==============================] - 0s 766us/step - loss: 0.4776 - accuracy: 0.7787 - val_loss: 0.5129 - val_accuracy: 0.7486
# Epoch 101/150
# 224/224 [==============================] - 0s 765us/step - loss: 0.4795 - accuracy: 0.7721 - val_loss: 0.5053 - val_accuracy: 0.7598
# Epoch 102/150
# 224/224 [==============================] - 0s 746us/step - loss: 0.4781 - accuracy: 0.7740 - val_loss: 0.4850 - val_accuracy: 0.7665
# Epoch 103/150
# 224/224 [==============================] - 0s 766us/step - loss: 0.4795 - accuracy: 0.7714 - val_loss: 0.4894 - val_accuracy: 0.7626
# Epoch 104/150
# 224/224 [==============================] - 0s 795us/step - loss: 0.4784 - accuracy: 0.7764 - val_loss: 0.4839 - val_accuracy: 0.7693
# Epoch 105/150
# 224/224 [==============================] - 0s 748us/step - loss: 0.4784 - accuracy: 0.7726 - val_loss: 0.4913 - val_accuracy: 0.7654
# Epoch 106/150
# 224/224 [==============================] - 0s 777us/step - loss: 0.4782 - accuracy: 0.7745 - val_loss: 0.4994 - val_accuracy: 0.7570
# Epoch 107/150
# 224/224 [==============================] - 0s 757us/step - loss: 0.4784 - accuracy: 0.7718 - val_loss: 0.4862 - val_accuracy: 0.7710
# Epoch 108/150
# 224/224 [==============================] - 0s 752us/step - loss: 0.4790 - accuracy: 0.7728 - val_loss: 0.4842 - val_accuracy: 0.7665
# Epoch 109/150
# 224/224 [==============================] - 0s 787us/step - loss: 0.4793 - accuracy: 0.7726 - val_loss: 0.4829 - val_accuracy: 0.7710
# Epoch 110/150
# 224/224 [==============================] - 0s 768us/step - loss: 0.4785 - accuracy: 0.7696 - val_loss: 0.4939 - val_accuracy: 0.7592
# Epoch 111/150
# 224/224 [==============================] - 0s 770us/step - loss: 0.4781 - accuracy: 0.7742 - val_loss: 0.4838 - val_accuracy: 0.7671
# Epoch 112/150
# 224/224 [==============================] - 0s 771us/step - loss: 0.4795 - accuracy: 0.7710 - val_loss: 0.4921 - val_accuracy: 0.7637
# Epoch 113/150
# 224/224 [==============================] - 0s 763us/step - loss: 0.4789 - accuracy: 0.7707 - val_loss: 0.4849 - val_accuracy: 0.7788
# Epoch 114/150
# 224/224 [==============================] - 0s 776us/step - loss: 0.4783 - accuracy: 0.7703 - val_loss: 0.4854 - val_accuracy: 0.7699
# Epoch 115/150
# 224/224 [==============================] - 0s 794us/step - loss: 0.4788 - accuracy: 0.7726 - val_loss: 0.4900 - val_accuracy: 0.7693
# Epoch 116/150
# 224/224 [==============================] - 0s 763us/step - loss: 0.4793 - accuracy: 0.7725 - val_loss: 0.4931 - val_accuracy: 0.7620
# Epoch 117/150
# 224/224 [==============================] - 0s 745us/step - loss: 0.4791 - accuracy: 0.7711 - val_loss: 0.4835 - val_accuracy: 0.7755
# Epoch 118/150
# 224/224 [==============================] - 0s 753us/step - loss: 0.4783 - accuracy: 0.7704 - val_loss: 0.4932 - val_accuracy: 0.7688
# Epoch 119/150
# 224/224 [==============================] - 0s 741us/step - loss: 0.4785 - accuracy: 0.7750 - val_loss: 0.4988 - val_accuracy: 0.7637
# Epoch 120/150
# 224/224 [==============================] - 0s 768us/step - loss: 0.4791 - accuracy: 0.7696 - val_loss: 0.4836 - val_accuracy: 0.7716
# Epoch 121/150
# 224/224 [==============================] - 0s 835us/step - loss: 0.4783 - accuracy: 0.7733 - val_loss: 0.4896 - val_accuracy: 0.7648
# Epoch 122/150
# 224/224 [==============================] - 0s 745us/step - loss: 0.4779 - accuracy: 0.7757 - val_loss: 0.4846 - val_accuracy: 0.7783
# Epoch 123/150
# 224/224 [==============================] - 0s 740us/step - loss: 0.4772 - accuracy: 0.7757 - val_loss: 0.5012 - val_accuracy: 0.7620
# Epoch 124/150
# 224/224 [==============================] - 0s 806us/step - loss: 0.4779 - accuracy: 0.7735 - val_loss: 0.4862 - val_accuracy: 0.7688
# Epoch 125/150
# 224/224 [==============================] - 0s 780us/step - loss: 0.4780 - accuracy: 0.7739 - val_loss: 0.4871 - val_accuracy: 0.7671
# Epoch 126/150
# 224/224 [==============================] - 0s 776us/step - loss: 0.4787 - accuracy: 0.7742 - val_loss: 0.4957 - val_accuracy: 0.7660
# Epoch 127/150
# 224/224 [==============================] - 0s 858us/step - loss: 0.4791 - accuracy: 0.7718 - val_loss: 0.5178 - val_accuracy: 0.7447
# Epoch 128/150
# 224/224 [==============================] - 0s 796us/step - loss: 0.4793 - accuracy: 0.7711 - val_loss: 0.4971 - val_accuracy: 0.7648
# Epoch 129/150
# 224/224 [==============================] - 0s 826us/step - loss: 0.4783 - accuracy: 0.7724 - val_loss: 0.4843 - val_accuracy: 0.7766
# Epoch 130/150
# 224/224 [==============================] - 0s 848us/step - loss: 0.4770 - accuracy: 0.7740 - val_loss: 0.4916 - val_accuracy: 0.7704
# Epoch 131/150
# 224/224 [==============================] - 0s 818us/step - loss: 0.4784 - accuracy: 0.7721 - val_loss: 0.4906 - val_accuracy: 0.7604
# Epoch 132/150
# 224/224 [==============================] - 0s 798us/step - loss: 0.4777 - accuracy: 0.7710 - val_loss: 0.4851 - val_accuracy: 0.7721
# Epoch 133/150
# 224/224 [==============================] - 0s 770us/step - loss: 0.4791 - accuracy: 0.7704 - val_loss: 0.5222 - val_accuracy: 0.7508
# Epoch 134/150
# 224/224 [==============================] - 0s 824us/step - loss: 0.4775 - accuracy: 0.7739 - val_loss: 0.4896 - val_accuracy: 0.7671
# Epoch 135/150
# 224/224 [==============================] - 0s 787us/step - loss: 0.4782 - accuracy: 0.7719 - val_loss: 0.4866 - val_accuracy: 0.7710
# Epoch 136/150
# 224/224 [==============================] - 0s 738us/step - loss: 0.4777 - accuracy: 0.7749 - val_loss: 0.4892 - val_accuracy: 0.7732
# Epoch 137/150
# 224/224 [==============================] - 0s 783us/step - loss: 0.4787 - accuracy: 0.7721 - val_loss: 0.4857 - val_accuracy: 0.7699
# Epoch 138/150
# 224/224 [==============================] - 0s 787us/step - loss: 0.4786 - accuracy: 0.7726 - val_loss: 0.4874 - val_accuracy: 0.7766
# Epoch 139/150
# 224/224 [==============================] - 0s 727us/step - loss: 0.4778 - accuracy: 0.7719 - val_loss: 0.4859 - val_accuracy: 0.7716
# Epoch 140/150
# 224/224 [==============================] - 0s 741us/step - loss: 0.4782 - accuracy: 0.7725 - val_loss: 0.4863 - val_accuracy: 0.7660
# Epoch 141/150
# 224/224 [==============================] - 0s 747us/step - loss: 0.4774 - accuracy: 0.7754 - val_loss: 0.4864 - val_accuracy: 0.7704
# Epoch 142/150
# 224/224 [==============================] - 0s 734us/step - loss: 0.4772 - accuracy: 0.7754 - val_loss: 0.4849 - val_accuracy: 0.7716
# Epoch 143/150
# 224/224 [==============================] - 0s 749us/step - loss: 0.4775 - accuracy: 0.7747 - val_loss: 0.5166 - val_accuracy: 0.7385
# Epoch 144/150
# 224/224 [==============================] - 0s 824us/step - loss: 0.4779 - accuracy: 0.7761 - val_loss: 0.4936 - val_accuracy: 0.7609
# Epoch 145/150
# 224/224 [==============================] - 0s 773us/step - loss: 0.4777 - accuracy: 0.7742 - val_loss: 0.5018 - val_accuracy: 0.7581
# Epoch 146/150
# 224/224 [==============================] - 0s 795us/step - loss: 0.4781 - accuracy: 0.7753 - val_loss: 0.4882 - val_accuracy: 0.7688
# Epoch 147/150
# 224/224 [==============================] - 0s 751us/step - loss: 0.4774 - accuracy: 0.7764 - val_loss: 0.5239 - val_accuracy: 0.7514
# Epoch 148/150
# 224/224 [==============================] - 0s 739us/step - loss: 0.4781 - accuracy: 0.7750 - val_loss: 0.4862 - val_accuracy: 0.7704
# Epoch 149/150
# 224/224 [==============================] - 0s 819us/step - loss: 0.4787 - accuracy: 0.7736 - val_loss: 0.4956 - val_accuracy: 0.7654
# Epoch 150/150
# 224/224 [==============================] - 0s 745us/step - loss: 0.4771 - accuracy: 0.7743 - val_loss: 0.5168 - val_accuracy: 0.7380

# %%
model.evaluate(test_X, test_y)[1]
# Out:
# 70/70 [==============================] - 0s 535us/step - loss: 0.4807 - accuracy: 0.7734
# 0.7733989953994751

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Loss Train', 'Loss Value', 'Accuracy Train', 'Accuracy Value'], loc='best')
plt.show()

# %% [markdown]
# ### Boosting

# %%
n_learning_rate_steps, n_folds = 10, 10
learninn_learning_rate_steps, n_folds = 10, 10
learning_rates = np.linspace(0.1, 1.0, num=n_learning_rate_steps)
splitter = StratifiedKFold(n_splits=n_folds, shuffle=True)
trn_err = np.zeros((n_learning_rate_steps, n_folds))
val_err = np.zeros((n_learning_rate_steps, n_folds))
stump = DecisionTreeClassifier(max_depth=1, random_state = 100)
 
for i, rate in enumerate(learning_rates):
    for j, (trn, val) in enumerate(splitter.split(train_X, train_y)):
        model = AdaBoostClassifier(algorithm='SAMME', base_estimator=stump, 
                                   n_estimators=10, learning_rate=rate)
        model.fit(train_X.values[trn, :], train_y.values[trn])
        trn_err[i, j] = 1 - accuracy_score(train_y.values[trn], model.predict(train_X.values[trn, :]))
        val_err[i, j] = 1 - accuracy_score(train_y.values[val], model.predict(train_X.values[val, :]))
trn_err = np.mean(trn_err, axis=1)
val_err = np.mean(val_err, axis=1)
print(f'Training Error {trn_err}, Value Error {val_err}')
# Out:
# Training Error [0.29281617 0.2505693  0.22825759 0.22467356 0.22374034 0.22336703
#  0.22020636 0.21984558 0.21378536 0.22442469], Value Error [0.29488084 0.2518767  0.22925293 0.22779867 0.22600432 0.22544416
#  0.22320678 0.21995553 0.21446942 0.22858179]

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(4, 4))

ax.plot(learning_rates, trn_err, marker='o', c=cm[0], markeredgecolor='w', linewidth=2)
ax.plot(learning_rates, val_err, marker='s', c=cm[1], markeredgecolor='w', linewidth=2)
ax.legend(['Train err', 'Validation err'])
ax.set_xlabel('Learning rate')
ax.set_ylabel('Error (%)')

fig.tight_layout()

# %%
n_learning_rate_steps, n_folds = 10, 10
learning_rates = np.linspace(0.1, 1.0, num=n_learning_rate_steps)
splitter = StratifiedKFold(n_splits=n_folds, shuffle=True)
trn_err = np.zeros((n_learning_rate_steps, n_folds))
val_err = np.zeros((n_learning_rate_steps, n_folds))
stump = DecisionTreeClassifier(max_depth=1, random_state = 100)

# %%
n_estimator_steps, n_folds = 2, 10
number_of_stumps = np.arange(2, 40, n_estimator_steps)
splitter = StratifiedKFold(n_splits=n_folds, shuffle=True)

trn_err = np.zeros((len(number_of_stumps), n_folds))
val_err = np.zeros((len(number_of_stumps), n_folds))

stump = DecisionTreeClassifier(max_depth=1)
for i, n_stumps in enumerate(number_of_stumps):
    for j, (trn, val) in enumerate(splitter.split(train_X, train_y)):
        model = AdaBoostClassifier(algorithm='SAMME', base_estimator=stump,
                                   n_estimators=n_stumps, learning_rate=0.9)
        model.fit(train_X.values[trn, :], train_y.values[trn])

        trn_err[i, j] = 1 - accuracy_score(train_y.values[trn], 
                                           model.predict(train_X.values[trn, :]))
        val_err[i, j] = 1 - accuracy_score(train_y.values[val], 
                                           model.predict(train_X.values[val, :]))

trn_err = np.mean(trn_err, axis=1)
val_err = np.mean(val_err, axis=1)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(4, 4))

ax.plot(number_of_stumps, trn_err, marker='o', c=cm[0], markeredgecolor='w', linewidth=2)
ax.plot(number_of_stumps, val_err, marker='s', c=cm[1], markeredgecolor='w', linewidth=2)
ax.legend(['Train err', 'Validation err'])
ax.set_xlabel('Number of decision stumps')
ax.set_ylabel('Error (%)')

fig.tight_layout()

# %%
shallow_tree = DecisionTreeClassifier(max_depth=1)
ensemble = AdaBoostClassifier(base_estimator=shallow_tree, 
                                  n_estimators=40, learning_rate=0.9)
ensemble.fit(train_X, train_y)
# Out:
# AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=1),
#                    learning_rate=0.9, n_estimators=40)

# %%
ypred = ensemble.predict(test_X)
acc = accuracy_score(test_y, ypred)
acc
# Out:
# 0.8208687863860278

# %% [markdown]
# ### SVM

# %%
fig, axes = plt.subplots(3, 3, figsize=(15, 15))

cv = ShuffleSplit(n_splits=10, test_size=0.2, random_state=0)

title = "Learning Curves (C5 layer MLP)"
clf1 = model = svm.SVC(kernel='rbf', C=15, gamma='auto')
clf1.fit(train_X, train_y)
plot_learning_curve(clf1, title, train_X, train_y, axes=axes[0, :], ylim=(0.7, 1.01),
                    cv=cv, n_jobs=4)

title = "Learning Curves (C30 layer MLP)"
clf2 = model = svm.SVC(kernel='rbf', C=30, gamma='auto')
clf2.fit(train_X, train_y)
plot_learning_curve(clf2, title, train_X, train_y, axes=axes[1,:], ylim=(0.7, 1.01),
                    cv=cv, n_jobs=4)

title = "Learning Curves (C45 layer MLP)"
clf3 = model = svm.SVC(kernel='rbf', C=45, gamma='auto')
clf3.fit(train_X, train_y)
plot_learning_curve(clf3, title, train_X, train_y, axes=axes[2,:], ylim=(0.7, 1.01),
                    cv=cv, n_jobs=4)


plt.show()

# %%
print(f'Best Score - C5: {clf1.score(test_X, test_y)*100:.2f}%')
print(f'Best Score - C30: {clf2.score(test_X, test_y)*100:.2f}%')
print(f'Best Score - C45: {clf3.score(test_X, test_y)*100:.2f}%')
# Out:
# Best Score - C5: 76.76%
# Best Score - C30: 77.52%
# Best Score - C45: 77.70%

# %% [markdown]
# ### KNN

# %%
# try to find best k value
scoreList = []
for i in range(2,40,2):
    knn2 = KNeighborsClassifier(n_neighbors = i)  # n_neighbors means k
    knn2.fit(train_X, train_y)
    fpr, tpr, thresholds = metrics.roc_curve(test_y, knn2.predict_proba(test_X)[:,1])
    # Calculate Area under the curve to display on the plot
    auc = metrics.roc_auc_score(test_y,knn2.predict(test_X))
    # Now, plot the computed values
    plt.plot(fpr, tpr, label='%s ROC (area = %0.2f)' % (f'# Nodes: {i}', auc))
    scoreList.append(knn2.score(test_X, test_y))
    # Custom settings for the plot

# %%
plt.plot(range(2,40,2), scoreList)
plt.xticks(np.arange(2,40,2))
plt.xlabel("K value")
plt.ylabel("Score")
plt.show()

# %%
acc = max(scoreList)*100
print(f'Maximum KNN Accuracy is {acc:.2f}%')
# Out:
# Maximum KNN Accuracy is 77.30%
